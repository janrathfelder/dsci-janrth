# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.preprocessing import MinMaxScaler

# custom modules
import pre_processing_mdb
import stl_trend_seasonality

import ols_assumptions_check 
import model_comparison

# %%
# Instantiate class:
pre_p = pre_processing_mdb.PreProcessing()

# %%
df1 = pd.read_csv('s3a://phmsbi-cpd-analytics-dev/jan_rathfelder/fr_eyl_mdb.csv')
df2 = pd.read_csv('s3a://phmsbi-cpd-analytics-dev/jan_rathfelder/it_eyl_mdb.csv')
df3 = pd.read_csv('s3a://phmsbi-cpd-analytics-dev/jan_rathfelder/uk_eyl_mdb.csv')

mdb = pd.concat([df1,df2,df3])

# %%
mdb = pre_p.create_date_format(df=mdb,
                               original_date_column='yrmo') # Create datetime object yyyymm

mdb = pre_p.time_index(date='yyyymm', 
                       df=mdb)

# %% [markdown]
# ### Data visualization

# %%
# monthly sales vs calls:

df = mdb[(mdb.yyyymm>='2021-07-01')&(mdb.yyyymm<='2022-07-01')].groupby(['yyyymm', 'country_cd'])[['total_calls','total_calls_cph','ae_nl_open', 'sales_unit']].sum().reset_index()

plt.figure(figsize=(10,5))
sns.scatterplot(data=df, x="total_calls", y="sales_unit", hue="country_cd")
plt.title('Monthly sales vs monthly calls from 2021-07-01 to 2022-07-01')
plt.show()

# %%
# Plot aggregated CPH and non-CPH actions:

df = mdb.groupby(['yyyymm','country_cd'])[['total_calls',
                                           'total_calls_cph',
                                           'total_calls_non_cph',
                                           'ae_nl_open', 
                                           'ae_nl_open_non_cph',
                                           'ae_nl_open_cph',
                                           'sales_unit']].sum().reset_index()

for idx in df.country_cd.unique():
    plt.figure(figsize=(6,2))
    plt.plot(df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].yyyymm,
            df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].total_calls_cph,
            label='total_calls_cph')
    plt.plot(df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].yyyymm,
             df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].total_calls_non_cph,
             label='total_calls_non_cph')
    plt.legend()
    plt.title('Total calls (CPH and non-CPH) for '+idx)
    plt.show()
    
for idx in df.country_cd.unique():
    plt.figure(figsize=(6,2))
    plt.plot(df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].yyyymm,
            df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].ae_nl_open_cph,
            label='ae_nl_cph')
    plt.plot(df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].yyyymm,
             df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].ae_nl_open_non_cph,
             label='ae_nl_non_cph')
    plt.legend()
    plt.title('Approved mails + newsletters (CPH and non-CPH) for '+idx)
    plt.show()

# %%
# Plot aggregated and normalized sales and CPH calls:

scaler = MinMaxScaler()

df = mdb.groupby(['yyyymm','country_cd'])[['total_calls','total_calls_cph','ae_nl_open', 'sales_unit']].sum().reset_index()

for idx in df.country_cd.unique():
    plt.figure(figsize=(6,2))
    plt.plot(df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].yyyymm,
             scaler.fit_transform(np.array(df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].total_calls_cph).reshape(-1,1)),
            label='total_calls_cph')
    plt.plot(df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].yyyymm,
             scaler.fit_transform(np.array(df[(df.country_cd==idx)&(df.yyyymm>='2021-07-01')&(df.yyyymm<='2022-07-01')].sales_unit).reshape(-1,1)),
            label='sales')
    plt.legend()
    plt.title('Normalized sales and total CPH calls for '+idx)
    plt.show()

# %%
# Aggregate CPH-calls and sales by month to view monthly seasonality pattern:

scaler = MinMaxScaler()

for ctr in mdb.country_cd.unique():
    df = mdb[mdb.country_cd==ctr].groupby(['month'])[['total_calls','total_calls_cph','ae_nl_open', 'sales_unit']].sum().reset_index()

    df['total_calls_cph'] = scaler.fit_transform(np.array([df.total_calls_cph]).reshape(-1, 1))
    df['sales_unit'] = scaler.fit_transform(np.array([df.sales_unit]).reshape(-1, 1))

    plt.figure(figsize=(12,5))
    sns.lineplot(data=df, x="month", y="sales_unit")
    sns.lineplot(data=df, x="month", y="total_calls_cph")
    plt.legend(['sales unit', 'total calls_cph'])
    plt.title(ctr)
    plt.show()

# %% [markdown]
# #### Apply STL decomposition

# %%
# Clean data before STL decomposition:

mdb = pre_p.remove_na(df=mdb,
                      variable='sales_unit',
                      grouping=['brand_nm','country_cd','cstmr_1_id'],
                      date='yyyymm',
                      min_date='2018-12-01',
                      max_date='2022-06-01')

mdb = pre_p.remove_zero(df=mdb, 
                        variable='sales_unit', 
                        grouping=['brand_nm','country_cd','cstmr_1_id'], 
                        date='yyyymm',
                        min_date='2021-05-01',
                        max_date='2022-06-01',
                        threshold=0)

# %%
# apply STL decomposition:
stl_decompose = stl_trend_seasonality.stl_decomposition('cstmr_1_id','yyyymm')

frames = []
sales_variable = 'sales_unit'

for country in mdb.country_cd.unique():
    for brand in mdb.brand_nm.unique():
        print(country,brand)
        df = stl_decompose.decomposition(df=mdb.query("country_cd == '{}' and brand_nm == '{}'".format(country, brand)), 
                                         target_value=sales_variable)
        frames += [df]

mdb = pd.concat(frames)
# Out:
# FR Eylea
# /home/jan_rathfelder/Development/scale-up-codebase/notebooks/impact_attr_presentation/stl_trend_seasonality.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[target_value+'_trend_stl'] = np.concatenate(trend)
# /home/jan_rathfelder/Development/scale-up-codebase/notebooks/impact_attr_presentation/stl_trend_seasonality.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[target_value+'_season_stl'] = np.concatenate(seasonality)
# /home/jan_rathfelder/Development/scale-up-codebase/notebooks/impact_attr_presentation/stl_trend_seasonality.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[target_value+'_detrended_deseasonalized_stl'] = np.concatenate(detrend_deseaon)
# IT Eylea
# GB Eylea
# /home/jan_rathfelder/Development/scale-up-codebase/env_4/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
# plot seasonality

for country in mdb.country_cd.unique():
    for brand in mdb.brand_nm.unique():
        sns.lineplot(data=mdb[(mdb.country_cd==country)&
                              (mdb.brand_nm==brand)], x="month", y="sales_unit_season_stl")
        plt.title(country+' '+brand)
        plt.show()

# %%
# plot trend

for country in mdb.country_cd.unique():
    for brand in mdb.brand_nm.unique():
        sns.lineplot(data=mdb[(mdb.country_cd==country)&
                              (mdb.brand_nm==brand)], x="month", y="sales_unit_trend_stl")
        plt.title(country+' '+brand)
        plt.show()

# %%
# Plot trend per area:

area = 'cstmr_1_id'
date = 'yyyymm'
target_trend = 'sales_unit_season_stl'

for country in mdb.country_cd.unique():
    for brand in mdb.brand_nm.unique():
        df_temp = mdb[(mdb.country_cd==country)&
                      (mdb.brand_nm==brand)]
        for idx in df_temp.cstmr_1_id.unique():
            df_temp[df_temp.cstmr_1_id==idx].groupby('yyyymm')[target_trend].sum().plot()
            plt.title(country+'_'+brand+': STL sales seasonality')
        plt.show()

# %%
# Plot trend per area:

area = 'cstmr_1_id'
date = 'yyyymm'
target_trend = 'sales_unit_trend_stl'

for country in mdb.country_cd.unique():
    for brand in mdb.brand_nm.unique():
        df_temp = mdb[(mdb.country_cd==country)&
                      (mdb.brand_nm==brand)]
        for idx in df_temp.cstmr_1_id.unique():
            df_temp[df_temp.cstmr_1_id==idx].groupby('yyyymm')[target_trend].sum().plot()
            plt.title(country+'_'+brand+': STL sales trend')
        plt.show()

# %%
# plot residual per area:

area = 'cstmr_1_id'
date = 'yyyymm'
target_trend = 'sales_unit_detrended_deseasonalized_stl'

for country in mdb.country_cd.unique():
    for brand in mdb.brand_nm.unique():
        df_temp = mdb[(mdb.country_cd==country)&
                      (mdb.brand_nm==brand)]
        for idx in df_temp.cstmr_1_id.unique():
            df_temp[df_temp.cstmr_1_id==idx].groupby('yyyymm')[target_trend].sum().plot()
            plt.title(country+'_'+brand+': STL sales residuals')
        plt.show()

# %% [markdown]
# ### Number of HCPs as confounder

# %%
# sales vs ae_nl for each group:

df = mdb[mdb.yyyymm>='2021-07-01'].groupby(['cstmr_1_id','country_cd'])[['total_calls',
                                                                         'total_calls_cph',
                                                                         'ae_nl_open',
                                                                         'sales_unit']].sum().reset_index()

plt.figure(figsize=(10,5))
sns.lmplot(data=df[(df.ae_nl_open<=370)&(df.sales_unit<=30000)], x="ae_nl_open", y="sales_unit", hue="country_cd",height=4.5, aspect=2)
plt.title('Approved mails and newsletter vs monthly calls from 2021-07-01 to 2022-07-01 aggregated by area')
plt.show()

# %%
# cleaning and scaling by HCPs:
# forward fill to replace missing hcp count:

mdb = pre_p.replace_missing_hcp_count_ffill(df=mdb,
                                            hcp_variable='total_hcp_cnt',
                                            grouping=['brand_nm','country_cd','cstmr_1_id'],
                                            date='yyyymm') 


# backward fill to replace missing hcp count:

mdb = pre_p.replace_missing_hcp_count_bfill(df=mdb,
                                            hcp_variable='total_hcp_cnt',
                                            grouping=['brand_nm','country_cd','cstmr_1_id'],
                                            date='yyyymm') 


mdb = pre_p.remove_zero(df=mdb, 
                        variable='total_hcp_cnt', 
                        grouping=['brand_nm','country_cd','cstmr_1_id'], 
                        date='yyyymm',
                        min_date='2018-12-01',
                        max_date='2022-09-01',
                        threshold=0)

mdb = pre_p.remove_na(df=mdb,
                      variable='sales_unit',
                      grouping=['brand_nm','country_cd','cstmr_1_id'],
                      date='yyyymm',
                      min_date='2018-12-01',
                      max_date='2022-09-01')

for col in ['ae_nl_open', 'sales_unit']:
    mdb = pre_p.scaling(df=mdb,
                        denominator='total_hcp_cnt', 
                        feature=col)

# %%
# plot:

df = mdb[mdb.yyyymm>='2021-07-01'].groupby(['cstmr_1_id','country_cd'])[['total_calls',
                                                                         'total_calls_cph',
                                                                         'ae_nl_open',
                                                                         'sales_unit']].sum().reset_index()

plt.figure(figsize=(10,5))
sns.lmplot(data=df, x="ae_nl_open", y="sales_unit", hue="country_cd",height=4.5, aspect=2)
plt.title('Approved mails and newsletter vs monthly calls from 2021-07-01 to 2022-07-01 aggregated by area after scaling by number of HCP')
plt.show()

# %% [markdown]
# ### Fit OLS

# %%
# loading a df with full pre-processing applied:

mdb2 = pd.read_csv('s3a://phmsbi-cpd-analytics-dev/jan_rathfelder/mdb_filtered_without_sondrio_conservative_updated_preprocess_.001zero_stl_sales.csv',
                  low_memory=False)
mdb2 = mdb2[mdb2.cstmr_1_id!='0']

# %%
# instantiate classes:

cl = ols_assumptions_check.ols_check(grouping='cstmr_1_id',
                                     time_window='yyyymm')
mc = model_comparison.ModelComparison()

# %%
target = 'sales_unit_detrended_deseasonalized_stl'

time_features = [
                 'sales_unit_detrended_deseasonalized_stl_shift1',
                 'sales_unit_detrended_deseasonalized_stl_shift2',
                 'sales_unit_detrended_deseasonalized_stl_shift3',
                 #'sales_unit_detrended_deseasonalized_stl_shift4',
                 #'sales_unit_detrended_deseasonalized_stl_shift5',
                 #'sales_unit_detrended_deseasonalized_stl_shift6',
   
                ]

features=[
    'total_calls_cph_trans_3mean',
    'total_calls_non_cph_trans_3mean',
    'ae_nl_open_cph_trans_3mean',
    'ae_nl_open_non_cph_trans_3mean',
    'evnt_attend_cph_trans_3mean',
    'evnt_attend_non_cph_trans_3mean'
            ]

dates_to_loop_eyl = [
                 ['2021-05-01', '2022-03-01'],
                 ['2021-05-01', '2022-04-01'],
                 ['2021-05-01', '2022-05-01'],
                 ['2021-05-01', '2022-06-01']
                    ] 

dates_to_loop_xrlt = [
                ['2020-05-01', '2022-03-01'],
                 ['2020-05-01', '2022-04-01'],
                ['2020-05-01', '2022-05-01'],
                 ['2020-05-01', '2022-06-01']
                    ]

# %%
dfz2 = mc.run_mode_training(df=mdb2,
                            target=target,
                            time_features=time_features,
                            features=features,
                            country='FR',
                            brand='Eylea',
                            area='cstmr_1_id',
                            hcp_scaler='total_hcp_cnt',
                            country_column='country_cd',
                            brand_column='brand_nm',
                            date_column='yyyymm',
                            dates_to_loop=dates_to_loop_eyl,
                            selected_algo='ols_positive_',
                            trend_variable='trend_season_stl',
                            show_classic_model_diagnostics=1,
                            show_additional_model_diagnostics=1,
                            show_summary_plots=1,
                            show_vif=1,
                            constant=0,
                            area_dummy=0)
display(dfz2)
# Out:
#                                            OLS Regression Results
# ============================================================================================================
# Dep. Variable:     sales_unit_detrended_deseasonalized_stl   R-squared (uncentered):                   0.941
# Model:                                                 OLS   Adj. R-squared (uncentered):              0.941
# Method:                                      Least Squares   F-statistic:                          1.481e+04
# Date:                                     Wed, 18 Jan 2023   Prob (F-statistic):                        0.00
# Time:                                             13:56:29   Log-Likelihood:                         -275.20
# No. Observations:                                     5489   AIC:                                      568.4
# Df Residuals:                                         5480   BIC:                                      627.9
# Df Model:                                                9
# Covariance Type:                                       HAC
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# total_calls_cph_trans_3mean                       -0.1144      0.191     -0.600      0.548      -0.488       0.259
# total_calls_non_cph_trans_3mean                    0.2430      0.036      6.689      0.000       0.172       0.314
# ae_nl_open_cph_trans_3mean                         0.2493      0.144      1.733      0.083      -0.033       0.531
# ae_nl_open_non_cph_trans_3mean                     0.3181      0.121      2.631      0.009       0.081       0.555
# evnt_attend_cph_trans_3mean                        0.6450      0.327      1.970      0.049       0.003       1.287
# evnt_attend_non_cph_trans_3mean                    0.0960      0.114      0.842      0.400      -0.128       0.320
# sales_unit_detrended_deseasonalized_stl_shift1     0.8380      0.061     13.714      0.000       0.718       0.958
# sales_unit_detrended_deseasonalized_stl_shift2    -0.0426      0.112     -0.378      0.705      -0.263       0.178
# sales_unit_detrended_deseasonalized_stl_shift3     0.1426      0.060      2.377      0.017       0.025       0.260
# ==============================================================================
# Omnibus:                     5115.611   Durbin-Watson:                   2.025
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1866094.936
# Skew:                           3.681   Prob(JB):                         0.00
# Kurtosis:                      93.028   Cond. No.                         216.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 8 lags and without small sample correction
# 2021-05-01 2022-03-01
#                                            OLS Regression Results
# ============================================================================================================
# Dep. Variable:     sales_unit_detrended_deseasonalized_stl   R-squared (uncentered):                   0.942
# Model:                                                 OLS   Adj. R-squared (uncentered):              0.942
# Method:                                      Least Squares   F-statistic:                          1.359e+04
# Date:                                     Wed, 18 Jan 2023   Prob (F-statistic):                        0.00
# Time:                                             13:56:29   Log-Likelihood:                         -277.22
# No. Observations:                                     5988   AIC:                                      572.4
# Df Residuals:                                         5979   BIC:                                      632.7
# Df Model:                                                9
# Covariance Type:                                       HAC
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# total_calls_cph_trans_3mean                        0.0059      0.205      0.029      0.977      -0.397       0.408
# total_calls_non_cph_trans_3mean                    0.2624      0.049      5.310      0.000       0.166       0.359
# ae_nl_open_cph_trans_3mean                         0.2092      0.101      2.068      0.039       0.011       0.408
# ae_nl_open_non_cph_trans_3mean                     0.2692      0.127      2.116      0.034       0.020       0.519
# evnt_attend_cph_trans_3mean                        0.5587      0.315      1.776      0.076      -0.058       1.175
# evnt_attend_non_cph_trans_3mean                    0.0801      0.106      0.758      0.449      -0.127       0.287
# sales_unit_detrended_deseasonalized_stl_shift1     0.8589      0.056     15.257      0.000       0.749       0.969
# sales_unit_detrended_deseasonalized_stl_shift2    -0.0204      0.096     -0.212      0.832      -0.209       0.169
# sales_unit_detrended_deseasonalized_stl_shift3     0.0988      0.047      2.103      0.035       0.007       0.191
# ==============================================================================
# Omnibus:                     5073.992   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1925026.969
# Skew:                           3.083   Prob(JB):                         0.00
# Kurtosis:                      90.621   Cond. No.                         193.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 8 lags and without small sample correction
# 2021-05-01 2022-04-01
#                                            OLS Regression Results
# ============================================================================================================
# Dep. Variable:     sales_unit_detrended_deseasonalized_stl   R-squared (uncentered):                   0.944
# Model:                                                 OLS   Adj. R-squared (uncentered):              0.943
# Method:                                      Least Squares   F-statistic:                          1.387e+04
# Date:                                     Wed, 18 Jan 2023   Prob (F-statistic):                        0.00
# Time:                                             13:56:30   Log-Likelihood:                         -233.18
# No. Observations:                                     6487   AIC:                                      484.4
# Df Residuals:                                         6478   BIC:                                      545.4
# Df Model:                                                9
# Covariance Type:                                       HAC
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# total_calls_cph_trans_3mean                       -0.0283      0.137     -0.207      0.836      -0.296       0.239
# total_calls_non_cph_trans_3mean                    0.2552      0.049      5.247      0.000       0.160       0.350
# ae_nl_open_cph_trans_3mean                         0.0898      0.099      0.910      0.363      -0.104       0.283
# ae_nl_open_non_cph_trans_3mean                     0.3071      0.108      2.850      0.004       0.096       0.518
# evnt_attend_cph_trans_3mean                        0.8385      0.360      2.329      0.020       0.133       1.544
# evnt_attend_non_cph_trans_3mean                    0.1109      0.102      1.091      0.275      -0.088       0.310
# sales_unit_detrended_deseasonalized_stl_shift1     0.8665      0.057     15.268      0.000       0.755       0.978
# sales_unit_detrended_deseasonalized_stl_shift2    -0.0171      0.096     -0.179      0.858      -0.205       0.171
# sales_unit_detrended_deseasonalized_stl_shift3     0.0879      0.046      1.891      0.059      -0.003       0.179
# ==============================================================================
# Omnibus:                     5312.727   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1983006.934
# Skew:                           2.905   Prob(JB):                         0.00
# Kurtosis:                      88.456   Cond. No.                         171.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 8 lags and without small sample correction
# 2021-05-01 2022-05-01
#                                            OLS Regression Results
# ============================================================================================================
# Dep. Variable:     sales_unit_detrended_deseasonalized_stl   R-squared (uncentered):                   0.945
# Model:                                                 OLS   Adj. R-squared (uncentered):              0.945
# Method:                                      Least Squares   F-statistic:                          1.479e+04
# Date:                                     Wed, 18 Jan 2023   Prob (F-statistic):                        0.00
# Time:                                             13:56:30   Log-Likelihood:                         -140.91
# No. Observations:                                     6986   AIC:                                      299.8
# Df Residuals:                                         6977   BIC:                                      361.5
# Df Model:                                                9
# Covariance Type:                                       HAC
# ==================================================================================================================
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# total_calls_cph_trans_3mean                       -0.0027      0.113     -0.024      0.981      -0.225       0.220
# total_calls_non_cph_trans_3mean                    0.2530      0.045      5.625      0.000       0.165       0.341
# ae_nl_open_cph_trans_3mean                         0.0030      0.059      0.050      0.960      -0.113       0.119
# ae_nl_open_non_cph_trans_3mean                     0.2878      0.097      2.974      0.003       0.098       0.477
# evnt_attend_cph_trans_3mean                        0.3764      0.265      1.420      0.156      -0.143       0.896
# evnt_attend_non_cph_trans_3mean                    0.0630      0.103      0.613      0.540      -0.139       0.265
# sales_unit_detrended_deseasonalized_stl_shift1     0.8685      0.054     16.024      0.000       0.762       0.975
# sales_unit_detrended_deseasonalized_stl_shift2    -0.0224      0.091     -0.247      0.805      -0.200       0.155
# sales_unit_detrended_deseasonalized_stl_shift3     0.0910      0.044      2.066      0.039       0.005       0.177
# ==============================================================================
# Omnibus:                     5663.115   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2083114.102
# Skew:                           2.859   Prob(JB):                         0.00
# Kurtosis:                      87.402   Cond. No.                         149.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors are heteroscedasticity and autocorrelation robust (HAC) using 8 lags and without small sample correction
# 2021-05-01 2022-06-01
# Durbin Watson for pooled sample:1.800882024114631
#                                                       vif
# ae_nl_open_non_cph_trans_3mean                   1.148469
# evnt_attend_cph_trans_3mean                      1.180846
# evnt_attend_non_cph_trans_3mean                  1.187853
# total_calls_non_cph_trans_3mean                  1.275546
# ae_nl_open_cph_trans_3mean                       1.381456
# sales_unit_detrended_deseasonalized_stl_shift1   1.481594
# sales_unit_detrended_deseasonalized_stl_shift3   1.490450
# total_calls_cph_trans_3mean                      1.732238
# sales_unit_detrended_deseasonalized_stl_shift2   2.051777
# const                                           27.739469
#                                              Features    2022-03-01  \
# 0                    total_calls_cph_trans_3mean_beta -1.143628e-01
# 1                total_calls_non_cph_trans_3mean_beta  2.430194e-01
# 2                     ae_nl_open_cph_trans_3mean_beta  2.493461e-01
# 3                 ae_nl_open_non_cph_trans_3mean_beta  3.181154e-01
# 4                    evnt_attend_cph_trans_3mean_beta  6.450023e-01
# 5                evnt_attend_non_cph_trans_3mean_beta  9.599322e-02
# 6   sales_unit_detrended_deseasonalized_stl_shift1...  8.380180e-01
# 7   sales_unit_detrended_deseasonalized_stl_shift2... -4.256143e-02
# 8   sales_unit_detrended_deseasonalized_stl_shift3...  1.426024e-01
# 9                  total_calls_cph_trans_3mean_pvalue  5.484434e-01
# 10             total_calls_non_cph_trans_3mean_pvalue  2.247595e-11
# 11                  ae_nl_open_cph_trans_3mean_pvalue  8.303545e-02
# 12              ae_nl_open_non_cph_trans_3mean_pvalue  8.506635e-03
# 13                 evnt_attend_cph_trans_3mean_pvalue  4.883279e-02
# 14             evnt_attend_non_cph_trans_3mean_pvalue  3.999828e-01
# 15  sales_unit_detrended_deseasonalized_stl_shift1...  8.386261e-43
# 16  sales_unit_detrended_deseasonalized_stl_shift2...  7.051431e-01
# 17  sales_unit_detrended_deseasonalized_stl_shift3...  1.747320e-02
# 18                 total_calls_cph_trans_3mean_impact -1.950398e-03
# 19             total_calls_non_cph_trans_3mean_impact  2.465423e-02
# 20                  ae_nl_open_cph_trans_3mean_impact  2.935027e-03
# 21              ae_nl_open_non_cph_trans_3mean_impact  5.738406e-03
# 22                 evnt_attend_cph_trans_3mean_impact  1.057749e-03
# 23             evnt_attend_non_cph_trans_3mean_impact  1.360624e-03
# 24                                     impact_overall  3.379564e-02
# 25                                               mape  1.473519e-01
#
#       2022-04-01    2022-05-01    2022-06-01
# 0   5.913785e-03 -2.833170e-02 -2.695542e-03
# 1   2.623969e-01  2.551675e-01  2.529774e-01
# 2   2.092324e-01  8.979447e-02  2.977963e-03
# 3   2.692030e-01  3.070838e-01  2.877608e-01
# 4   5.587379e-01  8.384614e-01  3.764497e-01
# 5   8.011264e-02  1.109130e-01  6.302768e-02
# 6   8.589102e-01  8.664588e-01  8.684513e-01
# 7  -2.039834e-02 -1.709654e-02 -2.239724e-02
# 8   9.884217e-02  8.793463e-02  9.095320e-02
# 9   9.770298e-01  8.356889e-01  9.810494e-01
# 10  1.095842e-07  1.549149e-07  1.856474e-08
# 11  3.867148e-02  3.628019e-01  9.599623e-01
# 12  3.432845e-02  4.372167e-03  2.942242e-03
# 13  7.574087e-02  1.983432e-02  1.555987e-01
# 14  4.486472e-01  2.753123e-01  5.399153e-01
# 15  1.488134e-52  1.246502e-52  8.675359e-58
# 16  8.323947e-01  8.582680e-01  8.048503e-01
# 17  3.543644e-02  5.859935e-02  3.883228e-02
# 18  1.206629e-04 -7.190018e-04 -8.021605e-05
# 19  2.725569e-02  2.680298e-02  2.707747e-02
# 20  3.348975e-03  2.231433e-03  1.103908e-04
# 21  4.655763e-03  5.165596e-03  4.930328e-03
# 22  1.075087e-03  1.942372e-03  1.144858e-03
# 23  1.120755e-03  1.539447e-03  9.048387e-04
# 24  3.757693e-02  3.696282e-02  3.408767e-02
# 25  1.468569e-01  1.460575e-01  1.449752e-01

# %% [markdown]
# ### Equations used in ppt

# %% [markdown]
# $y_{t} = \sum_{s=0}^{\inf} \alpha_{s} y_{t-s} + \sum_{j=0}^{\inf} \beta_{j} x_{t-j}$

# %% [markdown]
# $y_t = \alpha_{y} *  y_{t-1} + \beta_{ae\_nl} * ae\_nl_{3\_months} + beta_{calls} * calls_{3\_months} + beta_{events} * events_{3\_months}$
